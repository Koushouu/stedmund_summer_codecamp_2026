# %% [markdown]
# # Stock data analysis with Python

# %%
# First, import everything we need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime

# %% [markdown]
# ## Part 1: Getting Real Data from the Internet (APIs)

# %%
# Fetch Apple's stock data for the past year
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

ticker = yf.Ticker('AAPL')
aapl = ticker.history(start=start, end=end)

# What does this data look like?
aapl.head()

# %%
# Understand dataframe
# These Pandas methods help you understand the shape of your data
print(f"Shape: {aapl.shape}")      # How many rows and columns?
print(f"Columns: {list(aapl.columns)}")
print()
aapl.describe()                     # Summary statistics

# %%
# Excercise 1: Fetch your own stock (anything, if not sure try: Nvidia)
## Your code here!

# %%
# Excercise 1 (Bonus): Fetch multiple stocks at onece
# The stocks we'll analyze today
company_codes = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'BABA', 'TSLA']
company_names = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON", "ALIBABA", "TESLA"]

## Your code here!

# %% [markdown]
# ## Part 2: Visualizing Stock Prices

# %%
# Use matplotlib to visualize closing prices of all stocks

## Your code Here!

# %%
# Excercise 2: Design analysis to answer the following question:
# - Which stock has the best/ worst performance over the last year? (Hint: visulize normalized stock price)

## Your code Here!

# %% [markdown]
# ### Moving averages: identify the cross

# %%
# Calculate moving averages for all stocks
ma_days = [10, 20, 50]

for ma in ma_days:
    for company_code in company_codes:
        stock_data[company_code][f'MA_{ma}'] = stock_data[company_code]['Close'].rolling(window=ma).mean()

# %%
# Plot one stock with its moving averages and identify the golden/ death crosses

## Your code Here!

# %% [markdown]
# ## Part 3: Analyzing Returns and Risk
#
# $$\text{Daily Return} = \frac{\text{Price}_{\text{today}} - \text{Price}_{\text{yesterday}}}{\text{Price}_{\text{yesterday}}}$$

# %%
# Calculate daily returns for all stocks (Hint: use `.pct_change`)
## Your code here!

# %%
# Plot daily returns
## Your code here!

# %%
# Plot the distribution of returns (Show the spread and mean)
## Your code here!

# %%
# Plot the risk-return trade-off
## Your code here!

# %% [markdown]
# ### Exercise: Interpret the risk-return plot
#
# Discuss with your neighbor:
# 1. Which stock has the highest risk? Is its return proportionally higher?
# 2. If you could only invest in ONE stock, which would you choose and why?
# 3. What would a stock in the **top-left** corner of this plot represent?

# %% [markdown]
# ## Part 4: How are stocks related?

# %%
# Build a DataFrame of daily returns for all stocks
daily_returns_df = pd.DataFrame({
    code: stock_data[code]['Daily Return'] for code in company_codes
})

# Correlation matrix
correlation_matrix = daily_returns_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, 
            fmt='.2f', square=True, linewidths=1)
plt.title('Correlation Matrix of Daily Returns')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 5 (Bonus): sentiment analysis
# -> Check the other notebook
