# %% [markdown]
# You need to create an account at NewsAPI: https://newsapi.org/

# %%
STOCK_NAME = "TSLA"
COMPANY_NAME = "Tesla"

STOCK_ENDPOINT = "https://www.alphavantage.co/query"
NEWS_ENDPOINT = "https://newsapi.org/v2/everything"

NEWS_API_KEY = "c737a226a88b4fa0a69eb08d524ac412"

import requests

news_params = {
    "apiKey": NEWS_API_KEY,
    "qInTitle": COMPANY_NAME,
    "language": "en",
    "sortBy": "popularity",
}

new_responses = requests.get(url=NEWS_ENDPOINT, params=news_params)
artiles = new_responses.json()["articles"]
print(artiles)

# %%
import requests

news_params = {
    "apiKey": NEWS_API_KEY,
    "qInTitle": COMPANY_NAME,
    "language": "en",
    "sortBy": "popularity",
}

new_responses = requests.get(url="https://newsapi.org/v2/everything", params=news_params)

# %%
NEWS_ENDPOINT = "https://newsapi.org/"

NEWS_API_KEY = ##

import requests

news_params = {
    "apiKey": NEWS_API_KEY,
    "qInTitle": ##,
    "language": "en",
    "sortBy": "popularity",
}

new_responses = requests.get(url=NEWS_ENDPOINT, params=news_params)
##
print(artiles)
