# %% [markdown]
# # Jupyter cell types

# %%
# This is a code cell
print('Hello world!')

# %% [markdown]
# This is a markdown cell

# %%
# Basic arithmetics
print(3+5)
print(3**2)

# %% [markdown]
# # Concept of import

# %%
# Concepts of import
## Your code here!

# %% [markdown]
# --> Excercise 1: use concept of import + arithmetics

# %% [markdown]
# # Jupyter pitfall

# %%
# DEMO: Jupyter pitfall
a = 5
b = 6

# %%
a = a + 1

# %%
assert a == b, "A and B are different"

# %% [markdown]
# # Python list

# %%
m = [5.5, 6.3, 7.2, 8.0, 8.8]
m[0]

# %%
# .append

# %%
# max(), min(), +

# %% [markdown]
# Excercise 2: use for/ if to process a python list

# %% [markdown]
# # Function in py

# %%
## def ...

# %% [markdown]
# Excercise 3: create a python function to identify if a number is even/ odd

# %% [markdown]
# Try move the function to external *.py

# %% [markdown]
# # 10 mins break

# %% [markdown]
# # Numpy Intro

# %%
# import numpy as np

# %% [markdown]
# --> Excercise 4: Using numpy. Learn to read library documentation

# %% [markdown]
# # Matplotlib/ Skimage Intro

# %%
# import matplotlib.pyplot as plt

# %% [markdown]
# -> Excercise 5: Capstone
