# %%
# Excercise 1: Calculate the Euclidean distance between (x1, y1) and (x2, y2). 
# Hint: d(x1,y1,x2,y2) = sqrt((x1-x2)^2+(y1-y2)^2)

x1 = 5
y1 = 3

x2 = 8
y2 = 11

# dist = ...

# %%
# Excercise 2: Use "for" and "if" to print and append the element of the array "values" 
# to the array "target" if the array element is below the number specified by the "threshold".

values = [1,5,8,3,5,9,2,5,1,2,8,9]
target = []
threshold = 6

# for ...

# %%
# Excercise 3: Use "print", "%", "if" (and anything else) to construct a function to determine if 
# the argument is even number or odd number

# i.e.:
#  odd_or_even(2)
# Output: '2 is an even number'
#  odd_or_even(7)
# Output: '7 is an odd number'

# def ...

# %%
# Excercise 4.1:
# Use "numpy.random.randint" to generate an array of size 100 that contains random numbers between 1 and 10

# sample_array = ...

# %%
# Excercise 4.2:
# Use "np.unique" to find out unique elements of the random numbers array from the last exercise. The "unique" is like a dictionary of the input array elements.


# unique_element = ...

# %%
# Excercise 4.3:
# Use 'for ... in ...', 'sum()' to print how many times each unique elements appears in the original array in 8.1.

# %%
# Exercise 5: Generate 1000 random numbers, use a boolean mask to filter 
# values above the mean, and plot a histogram of the filtered values.
